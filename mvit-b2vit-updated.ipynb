# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, random_split, Subset, TensorDataset
from transformers import ViTModel
import os
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np
import cv2
from transformers.models.vit.modeling_vit import ViTEncoder

# Paths and parameters
folder_path = "/kaggle/input/monkeypox-skin-lesion-dataset/Augmented Images/Augmented Images"
subfolders = ['Monkeypox_augmented', 'Others_augmented']
image_size = (224, 224)
batch_size = 16
epochs = 30
learning_rate = 0.0001
gamma = 0.5  # Weight for combining deep and broad features

# Image transformations
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load dataset
data = []
labels = []
label_map = {subfolder: idx for idx, subfolder in enumerate(subfolders)}

for subfolder in subfolders:
    subfolder_path = os.path.join(folder_path, subfolder)
    for filename in os.listdir(subfolder_path):
        img_path = os.path.join(subfolder_path, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, image_size)
            data.append(img)
            labels.append(label_map[subfolder])

data = np.array(data).astype("float32")
labels = np.array(labels)

# Create PyTorch datasets
data = torch.tensor(data).permute(0, 3, 1, 2) / 255.0  # Normalize
labels = torch.tensor(labels)

# Create a TensorDataset
dataset = TensorDataset(data, labels)

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Broad Attention Mechanism
class BroadAttention(nn.Module):
    def __init__(self, hidden_size, num_layers):
        super(BroadAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.attention = nn.MultiheadAttention(embed_dim=hidden_size, num_heads=8)
        self.pool = nn.AdaptiveAvgPool1d(1)

    def forward(self, queries, keys, values):
        queries = torch.cat(queries, dim=1)
        keys = torch.cat(keys, dim=1)
        values = torch.cat(values, dim=1)
        attention_output, _ = self.attention(queries, keys, values)
        pooled_output = self.pool(attention_output.permute(0, 2, 1)).squeeze(-1)
        return pooled_output

# MVIT-Integrated B2VIT Model
class B2MVITNet(nn.Module):
    def __init__(self, vit_model_name, num_classes, gamma=0.5):
        super(B2MVITNet, self).__init__()
        self.vit = ViTModel.from_pretrained(vit_model_name, output_attentions=True)
        self.hidden_size = self.vit.config.hidden_size
        self.num_layers = len(self.vit.encoder.layer)
        self.gamma = gamma

        # Multiscale Fusion
        self.mvit_encoder = ViTEncoder(self.vit.config)
        self.mvit_attention = nn.MultiheadAttention(embed_dim=self.hidden_size, num_heads=8)
        
        # Broad Attention Mechanism
        self.broad_attention = BroadAttention(hidden_size=self.hidden_size, num_layers=self.num_layers)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(self.hidden_size * 2, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, pixel_values):
        outputs = self.vit(pixel_values, output_hidden_states=True)
        hidden_states = outputs.hidden_states
        deep_features = hidden_states[-1][:, 0, :]
        queries = [layer[:, 0, :].unsqueeze(1) for layer in hidden_states]
        broad_features = self.broad_attention(queries, queries, queries)

        # MVIT Feature Extraction
        mvit_outputs = self.mvit_encoder(hidden_states[-1])
        mvit_features = mvit_outputs.last_hidden_state[:, 0, :]

        # Combine Features
        combined_features = torch.cat((deep_features, self.gamma * broad_features + mvit_features), dim=1)
        logits = self.classifier(combined_features)
        return logits
# Out:
# 2025-04-18 06:18:10.569976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744957090.761806      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744957090.812228      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Training function without plotting
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        train_preds, train_targets = [], []

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            train_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            train_targets.extend(labels.cpu().numpy())

        train_loss /= len(train_loader.dataset)
        train_accuracy = accuracy_score(train_targets, train_preds)

        model.eval()
        val_loss = 0.0
        val_preds, val_targets = [], []

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
                val_targets.extend(labels.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        val_accuracy = accuracy_score(val_targets, val_preds)

        # Collect losses and accuracies for plotting later
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)

        # Print out the progress of training
        print(f"Epoch {epoch + 1}/{epochs}: Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
# Evaluation function
def evaluate_model(model, test_loader):
    model.eval()
    test_preds, test_targets = [], []
    tn, fp, fn, tp = 0, 0, 0, 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)

            test_preds.extend(preds.cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

            # Calculate confusion matrix components for specificity
            for true, pred in zip(labels.cpu().numpy(), preds.cpu().numpy()):
                if true == 0 and pred == 0:
                    tn += 1
                elif true == 0 and pred == 1:
                    fp += 1
                elif true == 1 and pred == 0:
                    fn += 1
                elif true == 1 and pred == 1:
                    tp += 1

    # Precision, recall, f1 score, and accuracy
    precision = precision_score(test_targets, test_preds, average='weighted')
    recall = recall_score(test_targets, test_preds, average='weighted')
    f1 = f1_score(test_targets, test_preds, average='weighted')
    accuracy = accuracy_score(test_targets, test_preds)

    # Specificity
    specificity = tn / (tn + fp)

    # Classification Report
    report = classification_report(test_targets, test_preds, target_names=subfolders)
    print(report)

    return accuracy, precision, recall, f1, specificity

# 5-Fold Cross-Validation loop
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_results = []
fold_specificity = []

# Lists to store the overall metrics across all folds for plotting
all_train_losses = []
all_val_losses = []
all_train_accuracies = []
all_val_accuracies = []

for fold, (train_indices, val_indices) in enumerate(kf.split(dataset)):
    print(f"\nFold {fold + 1}")
    
    # Reset lists at the start of each fold
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
    
    # Prepare the data loaders for the current fold
    train_subset = Subset(dataset, train_indices)
    val_subset = Subset(dataset, val_indices)

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # Initialize the model
    model = B2MVITNet("google/vit-base-patch16-224-in21k", num_classes=2, gamma=gamma).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Train the model
    train_model(model, train_loader, val_loader, criterion, optimizer, epochs)

    # Collect results for plotting later
    all_train_losses.extend(train_losses)
    all_val_losses.extend(val_losses)
    all_train_accuracies.extend(train_accuracies)
    all_val_accuracies.extend(val_accuracies)

    # Evaluate the model
    accuracy, precision, recall, f1, specificity = evaluate_model(model, val_loader)
    print(f"Fold {fold + 1} - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}, Specificity: {specificity:.4f}")
    fold_results.append((accuracy, precision, recall, f1))
    fold_specificity.append(specificity)

# Average Results
average_results = np.mean(fold_results, axis=0)
average_specificity = np.mean(fold_specificity)

print("\n5-Fold Cross-Validation Results:")
print(f"Average Accuracy: {average_results[0]:.4f}")
print(f"Average Precision: {average_results[1]:.4f}")
print(f"Average Recall: {average_results[2]:.4f}")
print(f"Average F1 Score: {average_results[3]:.4f}")
print(f"Average Specificity: {average_specificity:.4f}")

# Plotting the Loss vs Accuracy curve after all folds
plt.figure(figsize=(12, 6))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(range(epochs * 5), all_train_losses, label="Train Loss")
plt.plot(range(epochs * 5), all_val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(range(epochs * 5), all_train_accuracies, label="Train Accuracy")
plt.plot(range(epochs * 5), all_val_accuracies, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()
# Out:
# Fold 1
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True`. Falling back to eager attention. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# Epoch 1/30: Train Loss: 0.4574, Train Accuracy: 0.8394, Val Loss: 0.1649, Val Accuracy: 0.9374
# Epoch 2/30: Train Loss: 0.1270, Train Accuracy: 0.9526, Val Loss: 0.1607, Val Accuracy: 0.9703
# Epoch 3/30: Train Loss: 0.1022, Train Accuracy: 0.9687, Val Loss: 0.0287, Val Accuracy: 0.9937
# Epoch 4/30: Train Loss: 0.0390, Train Accuracy: 0.9886, Val Loss: 0.0242, Val Accuracy: 0.9890
# Epoch 5/30: Train Loss: 0.0634, Train Accuracy: 0.9812, Val Loss: 0.2625, Val Accuracy: 0.9092
# Epoch 6/30: Train Loss: 0.0496, Train Accuracy: 0.9851, Val Loss: 0.0764, Val Accuracy: 0.9765
# Epoch 7/30: Train Loss: 0.0253, Train Accuracy: 0.9922, Val Loss: 0.0211, Val Accuracy: 0.9922
# Epoch 8/30: Train Loss: 0.0176, Train Accuracy: 0.9949, Val Loss: 0.0480, Val Accuracy: 0.9844
# Epoch 9/30: Train Loss: 0.0318, Train Accuracy: 0.9902, Val Loss: 0.0697, Val Accuracy: 0.9812
# Epoch 10/30: Train Loss: 0.0183, Train Accuracy: 0.9953, Val Loss: 0.0287, Val Accuracy: 0.9906
# Epoch 11/30: Train Loss: 0.0169, Train Accuracy: 0.9949, Val Loss: 0.1187, Val Accuracy: 0.9765
# Epoch 12/30: Train Loss: 0.0647, Train Accuracy: 0.9835, Val Loss: 0.0264, Val Accuracy: 0.9953
# Epoch 13/30: Train Loss: 0.0002, Train Accuracy: 1.0000, Val Loss: 0.0262, Val Accuracy: 0.9953
# Epoch 14/30: Train Loss: 0.0002, Train Accuracy: 1.0000, Val Loss: 0.0216, Val Accuracy: 0.9969
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0215, Val Accuracy: 0.9969
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0212, Val Accuracy: 0.9969
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0214, Val Accuracy: 0.9969
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0218, Val Accuracy: 0.9969
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0222, Val Accuracy: 0.9969
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0228, Val Accuracy: 0.9969
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0230, Val Accuracy: 0.9969
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0228, Val Accuracy: 0.9969
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0228, Val Accuracy: 0.9969
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0230, Val Accuracy: 0.9969
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0231, Val Accuracy: 0.9953
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0232, Val Accuracy: 0.9953
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0234, Val Accuracy: 0.9953
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0237, Val Accuracy: 0.9953
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0240, Val Accuracy: 0.9953
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0240, Val Accuracy: 0.9953
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.99      1.00       303
#    Others_augmented       0.99      1.00      1.00       336
#
#            accuracy                           1.00       639
#           macro avg       1.00      1.00      1.00       639
#        weighted avg       1.00      1.00      1.00       639
#
# Fold 1 - Accuracy: 0.9953, Precision: 0.9953, Recall: 0.9953, F1 Score: 0.9953, Specificity: 0.9934
#
# Fold 2
# Epoch 1/30: Train Loss: 0.4896, Train Accuracy: 0.8218, Val Loss: 0.1433, Val Accuracy: 0.9515
# Epoch 2/30: Train Loss: 0.1218, Train Accuracy: 0.9640, Val Loss: 0.0985, Val Accuracy: 0.9531
# Epoch 3/30: Train Loss: 0.0593, Train Accuracy: 0.9808, Val Loss: 0.0934, Val Accuracy: 0.9859
# Epoch 5/30: Train Loss: 0.0408, Train Accuracy: 0.9886, Val Loss: 0.1341, Val Accuracy: 0.9609
# Epoch 6/30: Train Loss: 0.0705, Train Accuracy: 0.9788, Val Loss: 0.0736, Val Accuracy: 0.9812
# Epoch 7/30: Train Loss: 0.0559, Train Accuracy: 0.9843, Val Loss: 0.0650, Val Accuracy: 0.9844
# Epoch 8/30: Train Loss: 0.0074, Train Accuracy: 0.9973, Val Loss: 0.0419, Val Accuracy: 0.9906
# Epoch 9/30: Train Loss: 0.0285, Train Accuracy: 0.9918, Val Loss: 0.0646, Val Accuracy: 0.9781
# Epoch 10/30: Train Loss: 0.0537, Train Accuracy: 0.9843, Val Loss: 0.1970, Val Accuracy: 0.9577
# Epoch 11/30: Train Loss: 0.0307, Train Accuracy: 0.9906, Val Loss: 0.0715, Val Accuracy: 0.9844
# Epoch 12/30: Train Loss: 0.0061, Train Accuracy: 0.9973, Val Loss: 0.0760, Val Accuracy: 0.9844
# Epoch 13/30: Train Loss: 0.0002, Train Accuracy: 1.0000, Val Loss: 0.0279, Val Accuracy: 0.9953
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0296, Val Accuracy: 0.9953
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0299, Val Accuracy: 0.9969
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0305, Val Accuracy: 0.9969
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0305, Val Accuracy: 0.9953
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0311, Val Accuracy: 0.9953
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0319, Val Accuracy: 0.9937
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0325, Val Accuracy: 0.9969
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0326, Val Accuracy: 0.9953
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0328, Val Accuracy: 0.9969
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0330, Val Accuracy: 0.9969
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0332, Val Accuracy: 0.9969
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0337, Val Accuracy: 0.9969
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0342, Val Accuracy: 0.9969
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0343, Val Accuracy: 0.9969
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0347, Val Accuracy: 0.9969
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0348, Val Accuracy: 0.9969
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.99      1.00       289
#    Others_augmented       0.99      1.00      1.00       350
#
#            accuracy                           1.00       639
#           macro avg       1.00      1.00      1.00       639
#        weighted avg       1.00      1.00      1.00       639
#
# Fold 2 - Accuracy: 0.9969, Precision: 0.9969, Recall: 0.9969, F1 Score: 0.9969, Specificity: 0.9931
#
# Fold 3
# Epoch 1/30: Train Loss: 0.4862, Train Accuracy: 0.8125, Val Loss: 0.1806, Val Accuracy: 0.9326
# Epoch 2/30: Train Loss: 0.1338, Train Accuracy: 0.9495, Val Loss: 0.0797, Val Accuracy: 0.9702
# Epoch 3/30: Train Loss: 0.0878, Train Accuracy: 0.9734, Val Loss: 0.2931, Val Accuracy: 0.9232
# Epoch 4/30: Train Loss: 0.0485, Train Accuracy: 0.9847, Val Loss: 0.0862, Val Accuracy: 0.9702
# Epoch 5/30: Train Loss: 0.0393, Train Accuracy: 0.9883, Val Loss: 0.5585, Val Accuracy: 0.9451
# Epoch 6/30: Train Loss: 0.0642, Train Accuracy: 0.9843, Val Loss: 0.1959, Val Accuracy: 0.9592
# Epoch 7/30: Train Loss: 0.0566, Train Accuracy: 0.9863, Val Loss: 0.1684, Val Accuracy: 0.9420
# Epoch 8/30: Train Loss: 0.0432, Train Accuracy: 0.9867, Val Loss: 0.0830, Val Accuracy: 0.9890
# Epoch 9/30: Train Loss: 0.0108, Train Accuracy: 0.9965, Val Loss: 0.0530, Val Accuracy: 0.9875
# Epoch 10/30: Train Loss: 0.0844, Train Accuracy: 0.9808, Val Loss: 0.1385, Val Accuracy: 0.9389
# Epoch 11/30: Train Loss: 0.0599, Train Accuracy: 0.9839, Val Loss: 0.1076, Val Accuracy: 0.9734
# Epoch 12/30: Train Loss: 0.0326, Train Accuracy: 0.9933, Val Loss: 0.0460, Val Accuracy: 0.9859
# Epoch 13/30: Train Loss: 0.0290, Train Accuracy: 0.9926, Val Loss: 0.0481, Val Accuracy: 0.9875
# Epoch 14/30: Train Loss: 0.0194, Train Accuracy: 0.9953, Val Loss: 0.0465, Val Accuracy: 0.9890
# Epoch 15/30: Train Loss: 0.0009, Train Accuracy: 0.9996, Val Loss: 0.0698, Val Accuracy: 0.9859
# Epoch 16/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0760, Val Accuracy: 0.9859
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0736, Val Accuracy: 0.9859
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0734, Val Accuracy: 0.9859
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0745, Val Accuracy: 0.9859
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0761, Val Accuracy: 0.9859
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0769, Val Accuracy: 0.9859
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0770, Val Accuracy: 0.9875
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0779, Val Accuracy: 0.9875
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0763, Val Accuracy: 0.9875
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0768, Val Accuracy: 0.9875
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0783, Val Accuracy: 0.9875
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0788, Val Accuracy: 0.9875
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0789, Val Accuracy: 0.9875
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0820, Val Accuracy: 0.9875
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0808, Val Accuracy: 0.9875
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.97      0.99       275
#    Others_augmented       0.98      1.00      0.99       363
#
#            accuracy                           0.99       638
#           macro avg       0.99      0.99      0.99       638
#        weighted avg       0.99      0.99      0.99       638
#
# Fold 3 - Accuracy: 0.9875, Precision: 0.9876, Recall: 0.9875, F1 Score: 0.9874, Specificity: 0.9745
#
# Fold 4
# Epoch 1/30: Train Loss: 0.3826, Train Accuracy: 0.8626, Val Loss: 0.2707, Val Accuracy: 0.9248
# Epoch 2/30: Train Loss: 0.1325, Train Accuracy: 0.9542, Val Loss: 0.1545, Val Accuracy: 0.9514
# Epoch 3/30: Train Loss: 0.0680, Train Accuracy: 0.9800, Val Loss: 0.1086, Val Accuracy: 0.9655
# Epoch 4/30: Train Loss: 0.0591, Train Accuracy: 0.9843, Val Loss: 0.0462, Val Accuracy: 0.9812
# Epoch 5/30: Train Loss: 0.0173, Train Accuracy: 0.9969, Val Loss: 0.0746, Val Accuracy: 0.9812
# Epoch 6/30: Train Loss: 0.0632, Train Accuracy: 0.9832, Val Loss: 0.0900, Val Accuracy: 0.9734
# Epoch 7/30: Train Loss: 0.0455, Train Accuracy: 0.9886, Val Loss: 0.1417, Val Accuracy: 0.9608
# Epoch 8/30: Train Loss: 0.0355, Train Accuracy: 0.9894, Val Loss: 0.2283, Val Accuracy: 0.9561
# Epoch 9/30: Train Loss: 0.0273, Train Accuracy: 0.9930, Val Loss: 0.1250, Val Accuracy: 0.9624
# Epoch 10/30: Train Loss: 0.0510, Train Accuracy: 0.9875, Val Loss: 0.0603, Val Accuracy: 0.9781
# Epoch 11/30: Train Loss: 0.0531, Train Accuracy: 0.9859, Val Loss: 0.1638, Val Accuracy: 0.9342
# Epoch 12/30: Train Loss: 0.0298, Train Accuracy: 0.9941, Val Loss: 0.0434, Val Accuracy: 0.9875
# Epoch 13/30: Train Loss: 0.0009, Train Accuracy: 0.9996, Val Loss: 0.0090, Val Accuracy: 0.9984
# Epoch 14/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0089, Val Accuracy: 0.9984
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0092, Val Accuracy: 0.9984
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0097, Val Accuracy: 0.9984
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0099, Val Accuracy: 0.9984
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0106, Val Accuracy: 0.9984
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0110, Val Accuracy: 0.9969
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0116, Val Accuracy: 0.9969
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0115, Val Accuracy: 0.9969
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0119, Val Accuracy: 0.9969
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0122, Val Accuracy: 0.9969
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0125, Val Accuracy: 0.9969
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0128, Val Accuracy: 0.9969
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0129, Val Accuracy: 0.9969
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0130, Val Accuracy: 0.9969
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0130, Val Accuracy: 0.9969
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0131, Val Accuracy: 0.9969
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0134, Val Accuracy: 0.9969
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.99      1.00       282
#    Others_augmented       0.99      1.00      1.00       356
#
#            accuracy                           1.00       638
#           macro avg       1.00      1.00      1.00       638
#        weighted avg       1.00      1.00      1.00       638
#
# Fold 4 - Accuracy: 0.9969, Precision: 0.9969, Recall: 0.9969, F1 Score: 0.9969, Specificity: 0.9929
#
# Fold 5
# Epoch 1/30: Train Loss: 0.4535, Train Accuracy: 0.8273, Val Loss: 0.1736, Val Accuracy: 0.9342
# Epoch 2/30: Train Loss: 0.1519, Train Accuracy: 0.9444, Val Loss: 0.2884, Val Accuracy: 0.8762
# Epoch 3/30: Train Loss: 0.0928, Train Accuracy: 0.9679, Val Loss: 0.0983, Val Accuracy: 0.9687
# Epoch 4/30: Train Loss: 0.0419, Train Accuracy: 0.9894, Val Loss: 0.0626, Val Accuracy: 0.9734
# Epoch 5/30: Train Loss: 0.0409, Train Accuracy: 0.9883, Val Loss: 0.0383, Val Accuracy: 0.9875
# Epoch 6/30: Train Loss: 0.0231, Train Accuracy: 0.9914, Val Loss: 0.0360, Val Accuracy: 0.9812
# Epoch 7/30: Train Loss: 0.0351, Train Accuracy: 0.9910, Val Loss: 0.0191, Val Accuracy: 0.9906
# Epoch 9/30: Train Loss: 0.0550, Train Accuracy: 0.9851, Val Loss: 0.1814, Val Accuracy: 0.9655
# Epoch 10/30: Train Loss: 0.1190, Train Accuracy: 0.9699, Val Loss: 0.0819, Val Accuracy: 0.9639
# Epoch 11/30: Train Loss: 0.0195, Train Accuracy: 0.9930, Val Loss: 0.1135, Val Accuracy: 0.9796
# Epoch 12/30: Train Loss: 0.0305, Train Accuracy: 0.9949, Val Loss: 0.1081, Val Accuracy: 0.9781
# Epoch 13/30: Train Loss: 0.0038, Train Accuracy: 0.9988, Val Loss: 0.3655, Val Accuracy: 0.9389
# Epoch 14/30: Train Loss: 0.0576, Train Accuracy: 0.9832, Val Loss: 0.0245, Val Accuracy: 0.9953
# Epoch 15/30: Train Loss: 0.0010, Train Accuracy: 1.0000, Val Loss: 0.0077, Val Accuracy: 0.9953
# Epoch 16/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0068, Val Accuracy: 0.9969
# Epoch 17/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0053, Val Accuracy: 0.9969
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0051, Val Accuracy: 0.9969
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0051, Val Accuracy: 0.9969
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0047, Val Accuracy: 0.9969
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0048, Val Accuracy: 0.9969
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0052, Val Accuracy: 0.9969
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0053, Val Accuracy: 0.9969
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0053, Val Accuracy: 0.9969
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0050, Val Accuracy: 0.9969
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0051, Val Accuracy: 0.9969
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0050, Val Accuracy: 0.9969
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0050, Val Accuracy: 0.9969
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0049, Val Accuracy: 0.9969
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0047, Val Accuracy: 0.9969
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.99      1.00       279
#    Others_augmented       0.99      1.00      1.00       359
#
#            accuracy                           1.00       638
#           macro avg       1.00      1.00      1.00       638
#        weighted avg       1.00      1.00      1.00       638
#
# Fold 5 - Accuracy: 0.9969, Precision: 0.9969, Recall: 0.9969, F1 Score: 0.9969, Specificity: 0.9928
#
# 5-Fold Cross-Validation Results:
# Average Accuracy: 0.9947
# Average Precision: 0.9947
# Average Recall: 0.9947
# Average F1 Score: 0.9947
# Average Specificity: 0.9894

# %%
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(model, test_loader):
    model.eval()
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            
            all_probs.extend(probs.cpu().numpy())

    # Convert lists to numpy arrays
    all_labels = np.array(all_labels)
    all_probs = np.array(all_probs)

    

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(all_labels, all_probs[:, 1])  # Assuming binary classification (class 1 is positive)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrix(model, test_loader):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    cm = confusion_matrix(all_labels, all_preds)

    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=['Monkeypox', 'Others'], yticklabels=['Monkeypox', 'Others'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
plot_roc_curve(model, val_loader)  # For ROC AUC curve
plot_confusion_matrix(model, val_loader)  # For Confusion Matrix

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math
from torchvision import transforms
from PIL import Image
from transformers import ViTForImageClassification

def generate_vit_gradcam(model, image, target_class, device):
    model.eval()

    # Hook to capture activations and gradients
    activations, gradients = None, None

    def forward_hook(module, input, output):
        nonlocal activations
        activations = output  # Capture the output activations

    def backward_hook(module, grad_in, grad_out):
        nonlocal gradients
        gradients = grad_out[0]  # Capture the gradients

    # Register hooks on the last encoder block's output
    last_layer = model.vit.encoder.layer[-1].output
    forward_hook_handle = last_layer.register_forward_hook(forward_hook)
    backward_hook_handle = last_layer.register_backward_hook(backward_hook)

    # Forward pass
    image = image.to(device)
    logits = model(image).logits
    loss = logits[0, target_class]
    loss.backward()

    # Compute Grad-CAM
    pooled_gradients = torch.mean(gradients, dim=0)  # Global average pooling over batch
    activations = activations[0]  # Remove batch dimension

    # Remove the class token (first token)
    activations = activations[1:]  # Removing the class token (index 0)
    
    # Compute the Grad-CAM map
    gradcam_map = torch.einsum("ij,kj->i", [activations, pooled_gradients])  # Matrix multiplication

    # Reshape the Grad-CAM map to the grid size (only patch tokens)
    num_patches = gradcam_map.shape[0]
    grid_size = int(math.sqrt(num_patches))
    gradcam_map = gradcam_map.view(grid_size, grid_size).cpu().detach().numpy()

    # Normalize Grad-CAM
    gradcam_map = np.maximum(gradcam_map, 0)  # Apply ReLU to remove negative values
    gradcam_map -= gradcam_map.min()  # Normalize to [0, 1]
    gradcam_map /= gradcam_map.max()
    gradcam_map = cv2.resize(gradcam_map, (224, 224))  # Resize to original image size

    # De-normalize the input image
    original_image = image.squeeze(0).cpu().detach().numpy().transpose(1, 2, 0)
    original_image = original_image * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406]
    original_image = np.clip(original_image, 0, 1)

    # Plot Grad-CAM overlay
    plt.imshow(original_image)
    plt.imshow(gradcam_map, alpha=0.5, cmap='jet')
    plt.title(f"Grad-CAM for class {target_class}")
    plt.axis("off")
    plt.show()

    # Remove hooks
    forward_hook_handle.remove()
    backward_hook_handle.remove()

# Load the model and preprocess the image
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k").to(device)

image_path = "/kaggle/input/monkeypox-skin-lesion-dataset/Augmented Images/Augmented Images/Monkeypox_augmented/M01_02_01.jpg"
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Prepare the input image
sample_image = Image.open(image_path).convert("RGB")
sample_image_tensor = transform(sample_image).unsqueeze(0)

# Generate Grad-CAM
generate_vit_gradcam(model, sample_image_tensor, target_class=1, device=device)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1827: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %%
import matplotlib.pyplot as plt

# Accuracy values (in percentage) for MVIT-B2VIT
accuracies = [99.53, 99.69,98.75, 99.69, 99.69]
folds = [1, 2, 3, 4, 5]

plt.figure(figsize=(6, 4))
plt.plot(folds, accuracies, marker='o', color='navy', linewidth=2)
plt.xlabel('Fold')
plt.ylabel('Accuracy (%)')
plt.title('MVIT-B2VIT (Proposed)')
plt.grid(True)
plt.legend(['MVIT-B2VIT (Proposed)'], loc='lower right')
plt.tight_layout()
plt.show()
